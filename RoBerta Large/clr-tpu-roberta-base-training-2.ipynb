# %% [markdown]
# # Versions
# * Version1 : using ragnars method of reducing step size CV: 0.3299  LB: 0.491
# * Version 2: removing early stopping CV: 0.2315 LB: 0.497
# * Version 3 : using roberta large CV: 0.2217  LB:

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.model_selection import KFold,StratifiedKFold,train_test_split
from sklearn.metrics import mean_squared_error as mse
from sklearn.svm import SVR

import h5py

import tensorflow as tf 
from tensorflow.keras.layers import Layer,Input,LSTM,Bidirectional,Embedding,Dense, Conv1D, Dropout , MaxPool1D , MaxPooling1D, GlobalAveragePooling2D , GlobalAveragePooling1D
from tensorflow.keras.metrics import RootMeanSquaredError
from tensorflow.keras.models import Model,load_model,save_model, model_from_json , Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ReduceLROnPlateau,ModelCheckpoint, EarlyStopping ,LearningRateScheduler
from tensorflow.keras import backend as K
from tensorflow.keras.activations import tanh, softmax
import tensorflow_addons as tfa

from transformers import RobertaTokenizerFast,TFRobertaModel,TFAutoModel,AutoConfig

# %% [markdown]
# # Hyper parameters

# %%
max_len = 250
batch_size = 24
AUTOTUNE = tf.data.AUTOTUNE
SEED = 123
MODEL=['bert-base-uncased' ,'roberta-base' , 'roberta-large']

model_name = MODEL[2]

import os
os.makedirs("./result")

save_dir="./result"

# %%
paths=["/kaggle/input/commonlitreadabilityprize/sample_submission.csv",
"/kaggle/input/commonlitreadabilityprize/train.csv",
"/kaggle/input/commonlitreadabilityprize/test.csv"]

df_train=pd.read_csv(paths[1])
df_test=pd.read_csv(paths[2])
df_ss=pd.read_csv(paths[0])

# %%
df_train = df_train.drop(['url_legal','license','standard_error'],axis='columns')
df_test = df_test.drop(['url_legal','license'],axis='columns')

# %%
df_train.columns, df_test.columns
# Out:
# (Index(['id', 'excerpt', 'target'], dtype='object'),
#  Index(['id', 'excerpt'], dtype='object'))

# %%
X= df_train['excerpt']
y=df_train['target']

X_test = df_test['excerpt']

# %% [markdown]
# # Define Tokenizer

# %%
tokenizer_path = "../input/huggingface-roberta/roberta-large"
tokenizer = RobertaTokenizerFast.from_pretrained(tokenizer_path)
tokenizer.save_pretrained("./result/roberta-tokenizer")
# Out:
# ('./result/roberta-tokenizer/tokenizer_config.json',
#  './result/roberta-tokenizer/special_tokens_map.json',
#  './result/roberta-tokenizer/vocab.json',
#  './result/roberta-tokenizer/merges.txt',
#  './result/roberta-tokenizer/added_tokens.json',
#  './result/roberta-tokenizer/tokenizer.json')

# %% [markdown]
# # Dataset Prep

# %%
@tf.function
def map_function(encodings , target):
    input_ids = encodings['input_ids']
    attention_mask = encodings['attention_mask']
    
    target = tf.cast(target, tf.float32 )
    
    return {'input_ids': input_ids , 'attention_mask': attention_mask}, target

# %% [markdown]
# # Modelling

# %%
# Detect hardware, return appropriate distribution strategy
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is
    # set: this is always the case on Kaggle.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # Default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy()

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# Running on TPU  grpc://10.0.0.2:8470
# REPLICAS:  8

# %%
class RobertaBlock(Layer):
    def __init__(self, max_len ,name):
        super(RobertaBlock , self).__init__()
        self.config = AutoConfig.from_pretrained(name)
        self.config.update({"output_hidden_states":True,"hidden_dropout_prob": 0.0, "layer_norm_eps": 1e-7})
        self.roberta_model = TFAutoModel.from_pretrained(name , config = self.config)
        self.dense = Dense(1, activation='linear')
        
    def call(self,input_tensors):
        input_id = input_tensors[0]
        attention_mask = input_tensors[1]
        roberta_output = self.roberta_model.roberta(input_ids = input_id , attention_mask = attention_mask)
        roberta_output = roberta_output.hidden_states[-1]
        return roberta_output
    
class RegressionHead(Layer):
    def __init__(self):
        super(RegressionHead , self).__init__()
        self.dense = Dense(1, activation="linear")
    
    def call(self , input_tensors):
        x = self.dense(input_tensors)
        return x
        
class AttentionHead(Layer):
    def __init__(self):
        super(AttentionHead , self).__init__()
        self.dense1 = Dense(512)
        self.tanh =  tanh
        self.softmax = softmax
        self.dense2 = Dense(1,activation="softmax")
    
    def call(self , input_tensors):
        x = self.dense1(input_tensors)
        x = self.tanh(x)
        x = self.dense2(x)
        x = self.softmax(x , axis = 1)
        return x    


class CLRModel(Model):
    def __init__(self,max_len,name):
        super(CLRModel, self).__init__()
        self.roberta_model = RobertaBlock(max_len , name)
        self.attentionhead = AttentionHead()
        self.regressionhead = RegressionHead()
    
    def call(self,input_tensors):
        roberta_output = self.roberta_model(input_tensors)
        #print('shape of roberta output is' , roberta_output.shape)
        weights = self.attentionhead(roberta_output)
        #print('shape of attention head is',weights.shape)
        context_vector = tf.reduce_sum(weights * roberta_output, axis=1)
        #print("shape of context vector" , context_vector.shape)
        x = self.regressionhead(context_vector)
        return x
    
    def model(self):
        input_id = Input(shape = (max_len, ) ,dtype=tf.int32, name = 'input_ids')
        attention_mask = Input(shape=(max_len,) ,dtype=tf.int32, name = 'attention_mask')
        
        return Model(inputs = [input_id , attention_mask] , outputs = self.call([input_id , attention_mask]))

# %%
model_name
# Out:
# 'roberta-large'

# %%
model_name = "../input/huggingface-roberta/roberta-large"
with strategy.scope():
    model = CLRModel(max_len , model_name).model()

    model.compile(
          optimizer = tfa.optimizers.AdamW(learning_rate=  2e-5 , weight_decay = 1e-7 ),
          metrics = RootMeanSquaredError(),
          loss= "mse"
        )
# Out:
# Some layers from the model checkpoint at ../input/huggingface-roberta/roberta-large were not used when initializing TFRobertaModel: ['lm_head']
# - This IS expected if you are initializing TFRobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFRobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFRobertaModel were initialized from the model checkpoint at ../input/huggingface-roberta/roberta-large.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFRobertaModel for predictions without further training.

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_ids (InputLayer)          [(None, 250)]        0
# __________________________________________________________________________________________________
# attention_mask (InputLayer)     [(None, 250)]        0
# __________________________________________________________________________________________________
# roberta_block (RobertaBlock)    (None, 250, 1024)    355359744   input_ids[0][0]
#                                                                  attention_mask[0][0]
# __________________________________________________________________________________________________
# attention_head (AttentionHead)  (None, 250, 1)       525313      roberta_block[0][0]
# __________________________________________________________________________________________________
# tf.math.multiply (TFOpLambda)   (None, 250, 1024)    0           attention_head[0][0]
#                                                                  roberta_block[0][0]
# __________________________________________________________________________________________________
# tf.math.reduce_sum (TFOpLambda) (None, 1024)         0           tf.math.multiply[0][0]
# __________________________________________________________________________________________________
# regression_head (RegressionHead (None, 1)            1025        tf.math.reduce_sum[0][0]
# ==================================================================================================
# Total params: 355,886,082
# Trainable params: 355,886,082
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# # Kfold Training

# %%
scores=[]
iterations = 1
kfold = KFold(n_splits=5, shuffle= True , random_state = SEED)
for train_idx, test_idx in kfold.split(X,y):
    print("************** iteration",iterations,"**************")
    X_train = X.loc[train_idx]
    X_test = X.loc[test_idx]
    y_train = y.loc[train_idx]
    y_test = y.loc[test_idx]
    
    X_train = X_train.tolist()
    X_test = X_test.tolist()

    y_train = y_train.tolist()
    y_test = y_test.tolist()
    
    #tokenization
    print('tokenization')
    train_embeddings = tokenizer(X_train, truncation = True , padding = True , max_length=max_len)
    test_embeddings = tokenizer(X_test , truncation = True , padding =True , max_length = max_len)
    
    #print(train_embeddings.keys())
    train = tf.data.Dataset.from_tensor_slices((train_embeddings,y_train))

    train = (
            train
            .repeat()
            .shuffle(2048)
            .map(map_function, num_parallel_calls=AUTOTUNE)
            .batch(batch_size)
            .prefetch(AUTOTUNE)
        )
    
    test = tf.data.Dataset.from_tensor_slices((test_embeddings , y_test))
    test = (
        test
        .map(map_function, num_parallel_calls = AUTOTUNE)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
    )

    train_step = np.ceil(len(X_train)/(batch_size*16))    
    
    #Clearing backend session
    K.clear_session()
    print("Backend Cleared")
    
    #early_stopping=EarlyStopping(monitor="val_root_mean_squared_error",min_delta=0,patience=20,verbose=1,mode="min",restore_best_weights=True)
    #reduce_lr=ReduceLROnPlateau(monitor="val_root_mean_squared_error",factor=0.1,patience=2,min_lr= 1e-8 , verbose=1)
    model_checkpoint = ModelCheckpoint(f'{save_dir}/roberta_weight_fold_{iterations}.h5',
                                                        monitor = 'val_root_mean_squared_error', 
                                                 verbose = 1, 
                                                        save_best_only = True,
                                                        save_weights_only = True, 
                                                        mode = 'min')

    hist=model.fit(train, steps_per_epoch = train_step,validation_data=test,epochs= 70,callbacks = [model_checkpoint])

    #prediction
    print("predicting")
    model.load_weights(f'{save_dir}/roberta_weight_fold_{iterations}.h5')
    y_pred = model.predict(test)
    print(np.sqrt(mse(y_pred,y_test)))
    scores.append(np.sqrt(mse(y_pred,y_test)))
    
    #saving model
    #print("saving model")
    #localhost_save_option = tf.saved_model.SaveOptions(experimental_io_device="/job:localhost")
    #model.save_weights(f'{save_dir}/roberta_weight_fold_{iterations}.h5', options=localhost_save_option)
    iterations+=1
    
print("the final average rmse is ", np.mean(scores))
# Out:
# ************** iteration 1 **************
# tokenization
# Backend Cleared
# Epoch 1/70
# 6/6 [==============================] - 193s 6s/step - loss: 1.4421 - root_mean_squared_error: 1.1986 - val_loss: 1.2513 - val_root_mean_squared_error: 1.1186
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 1.11859, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 2/70
# 6/6 [==============================] - 3s 552ms/step - loss: 1.0865 - root_mean_squared_error: 1.0390 - val_loss: 0.9340 - val_root_mean_squared_error: 0.9664
#
# Epoch 00002: val_root_mean_squared_error improved from 1.11859 to 0.96645, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 3/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.7972 - root_mean_squared_error: 0.8920 - val_loss: 0.9268 - val_root_mean_squared_error: 0.9627
#
# Epoch 00003: val_root_mean_squared_error improved from 0.96645 to 0.96271, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 4/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.9130 - root_mean_squared_error: 0.9510 - val_loss: 0.7427 - val_root_mean_squared_error: 0.8618
#
# Epoch 00004: val_root_mean_squared_error improved from 0.96271 to 0.86183, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 5/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.6902 - root_mean_squared_error: 0.8270 - val_loss: 0.8144 - val_root_mean_squared_error: 0.9024
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.86183
# Epoch 6/70
# 6/6 [==============================] - 3s 568ms/step - loss: 0.9261 - root_mean_squared_error: 0.9603 - val_loss: 0.5163 - val_root_mean_squared_error: 0.7185
#
# Epoch 00006: val_root_mean_squared_error improved from 0.86183 to 0.71851, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 7/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.4306 - root_mean_squared_error: 0.6559 - val_loss: 0.3888 - val_root_mean_squared_error: 0.6236
#
# Epoch 00007: val_root_mean_squared_error improved from 0.71851 to 0.62356, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 8/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.2988 - root_mean_squared_error: 0.5460 - val_loss: 0.3850 - val_root_mean_squared_error: 0.6205
#
# Epoch 00008: val_root_mean_squared_error improved from 0.62356 to 0.62046, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 9/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.3393 - root_mean_squared_error: 0.5820 - val_loss: 0.3384 - val_root_mean_squared_error: 0.5818
#
# Epoch 00009: val_root_mean_squared_error improved from 0.62046 to 0.58176, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 10/70
# 6/6 [==============================] - 3s 566ms/step - loss: 0.3370 - root_mean_squared_error: 0.5800 - val_loss: 0.3232 - val_root_mean_squared_error: 0.5685
#
# Epoch 00010: val_root_mean_squared_error improved from 0.58176 to 0.56852, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 11/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.3902 - root_mean_squared_error: 0.6242 - val_loss: 0.4437 - val_root_mean_squared_error: 0.6661
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.56852
# Epoch 12/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.3124 - root_mean_squared_error: 0.5588 - val_loss: 0.3146 - val_root_mean_squared_error: 0.5609
#
# Epoch 00012: val_root_mean_squared_error improved from 0.56852 to 0.56093, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 13/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.4404 - root_mean_squared_error: 0.6632 - val_loss: 0.3125 - val_root_mean_squared_error: 0.5590
#
# Epoch 00013: val_root_mean_squared_error improved from 0.56093 to 0.55904, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 14/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.2889 - root_mean_squared_error: 0.5370 - val_loss: 0.3831 - val_root_mean_squared_error: 0.6189
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.55904
# Epoch 15/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.2058 - root_mean_squared_error: 0.4533 - val_loss: 0.2976 - val_root_mean_squared_error: 0.5455
#
# Epoch 00015: val_root_mean_squared_error improved from 0.55904 to 0.54548, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 16/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.2703 - root_mean_squared_error: 0.5191 - val_loss: 0.2843 - val_root_mean_squared_error: 0.5332
#
# Epoch 00016: val_root_mean_squared_error improved from 0.54548 to 0.53316, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 17/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.2542 - root_mean_squared_error: 0.5039 - val_loss: 0.2693 - val_root_mean_squared_error: 0.5190
#
# Epoch 00017: val_root_mean_squared_error improved from 0.53316 to 0.51898, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 18/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.2331 - root_mean_squared_error: 0.4822 - val_loss: 0.3205 - val_root_mean_squared_error: 0.5662
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.51898
# Epoch 19/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.2561 - root_mean_squared_error: 0.5054 - val_loss: 0.3033 - val_root_mean_squared_error: 0.5507
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.51898
# Epoch 20/70
# 6/6 [==============================] - 3s 560ms/step - loss: 0.2344 - root_mean_squared_error: 0.4801 - val_loss: 0.3271 - val_root_mean_squared_error: 0.5719
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.51898
# Epoch 21/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.2546 - root_mean_squared_error: 0.5019 - val_loss: 0.3219 - val_root_mean_squared_error: 0.5674
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.51898
# Epoch 22/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.1910 - root_mean_squared_error: 0.4364 - val_loss: 0.3249 - val_root_mean_squared_error: 0.5700
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.51898
# Epoch 23/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.1788 - root_mean_squared_error: 0.4220 - val_loss: 0.2730 - val_root_mean_squared_error: 0.5225
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.51898
# Epoch 24/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.1719 - root_mean_squared_error: 0.4145 - val_loss: 0.3202 - val_root_mean_squared_error: 0.5658
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.51898
# Epoch 25/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.1808 - root_mean_squared_error: 0.4250 - val_loss: 0.2653 - val_root_mean_squared_error: 0.5150
#
# Epoch 00025: val_root_mean_squared_error improved from 0.51898 to 0.51502, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 26/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.1224 - root_mean_squared_error: 0.3485 - val_loss: 0.2930 - val_root_mean_squared_error: 0.5413
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.51502
# Epoch 27/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.1584 - root_mean_squared_error: 0.3963 - val_loss: 0.2920 - val_root_mean_squared_error: 0.5404
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.51502
# Epoch 28/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.1749 - root_mean_squared_error: 0.4176 - val_loss: 0.2690 - val_root_mean_squared_error: 0.5187
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.51502
# Epoch 29/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.1376 - root_mean_squared_error: 0.3703 - val_loss: 0.2722 - val_root_mean_squared_error: 0.5217
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.51502
# Epoch 30/70
# 6/6 [==============================] - 4s 779ms/step - loss: 0.1700 - root_mean_squared_error: 0.4097 - val_loss: 0.2735 - val_root_mean_squared_error: 0.5230
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.51502
# Epoch 31/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.1090 - root_mean_squared_error: 0.3296 - val_loss: 0.2990 - val_root_mean_squared_error: 0.5468
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.51502
# Epoch 32/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0966 - root_mean_squared_error: 0.3093 - val_loss: 0.2659 - val_root_mean_squared_error: 0.5157
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.51502
# Epoch 33/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.1225 - root_mean_squared_error: 0.3495 - val_loss: 0.2557 - val_root_mean_squared_error: 0.5057
#
# Epoch 00033: val_root_mean_squared_error improved from 0.51502 to 0.50569, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 34/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0849 - root_mean_squared_error: 0.2911 - val_loss: 0.2516 - val_root_mean_squared_error: 0.5016
#
# Epoch 00034: val_root_mean_squared_error improved from 0.50569 to 0.50162, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 35/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0777 - root_mean_squared_error: 0.2782 - val_loss: 0.2630 - val_root_mean_squared_error: 0.5128
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.50162
# Epoch 36/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.1161 - root_mean_squared_error: 0.3402 - val_loss: 0.2706 - val_root_mean_squared_error: 0.5202
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.50162
# Epoch 37/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.1041 - root_mean_squared_error: 0.3226 - val_loss: 0.2503 - val_root_mean_squared_error: 0.5003
#
# Epoch 00037: val_root_mean_squared_error improved from 0.50162 to 0.50025, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 38/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.1192 - root_mean_squared_error: 0.3435 - val_loss: 0.2525 - val_root_mean_squared_error: 0.5025
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.50025
# Epoch 39/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0934 - root_mean_squared_error: 0.3046 - val_loss: 0.3196 - val_root_mean_squared_error: 0.5653
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.50025
# Epoch 40/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.1710 - root_mean_squared_error: 0.4115 - val_loss: 0.2507 - val_root_mean_squared_error: 0.5007
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.50025
# Epoch 41/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.0872 - root_mean_squared_error: 0.2925 - val_loss: 0.2547 - val_root_mean_squared_error: 0.5047
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.50025
# Epoch 42/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.1064 - root_mean_squared_error: 0.3259 - val_loss: 0.2830 - val_root_mean_squared_error: 0.5320
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.50025
# Epoch 43/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0807 - root_mean_squared_error: 0.2837 - val_loss: 0.2528 - val_root_mean_squared_error: 0.5028
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.50025
# Epoch 44/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.0655 - root_mean_squared_error: 0.2558 - val_loss: 0.2445 - val_root_mean_squared_error: 0.4945
#
# Epoch 00044: val_root_mean_squared_error improved from 0.50025 to 0.49448, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 45/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0464 - root_mean_squared_error: 0.2153 - val_loss: 0.2383 - val_root_mean_squared_error: 0.4882
#
# Epoch 00045: val_root_mean_squared_error improved from 0.49448 to 0.48821, saving model to ./result/roberta_weight_fold_1.h5
# Epoch 46/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0607 - root_mean_squared_error: 0.2463 - val_loss: 0.2555 - val_root_mean_squared_error: 0.5054
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.48821
# Epoch 47/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0511 - root_mean_squared_error: 0.2258 - val_loss: 0.2778 - val_root_mean_squared_error: 0.5271
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.48821
# Epoch 48/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0538 - root_mean_squared_error: 0.2317 - val_loss: 0.2880 - val_root_mean_squared_error: 0.5367
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.48821
# Epoch 49/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0571 - root_mean_squared_error: 0.2382 - val_loss: 0.2524 - val_root_mean_squared_error: 0.5024
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.48821
# Epoch 50/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0587 - root_mean_squared_error: 0.2416 - val_loss: 0.2734 - val_root_mean_squared_error: 0.5229
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.48821
# Epoch 51/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0611 - root_mean_squared_error: 0.2460 - val_loss: 0.2925 - val_root_mean_squared_error: 0.5409
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.48821
# Epoch 52/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0629 - root_mean_squared_error: 0.2505 - val_loss: 0.2458 - val_root_mean_squared_error: 0.4958
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.48821
# Epoch 53/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0610 - root_mean_squared_error: 0.2463 - val_loss: 0.2387 - val_root_mean_squared_error: 0.4885
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.48821
# Epoch 54/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0530 - root_mean_squared_error: 0.2297 - val_loss: 0.2791 - val_root_mean_squared_error: 0.5283
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.48821
# Epoch 55/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0691 - root_mean_squared_error: 0.2608 - val_loss: 0.2748 - val_root_mean_squared_error: 0.5243
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.48821
# Epoch 56/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.0461 - root_mean_squared_error: 0.2133 - val_loss: 0.2406 - val_root_mean_squared_error: 0.4906
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.48821
# Epoch 57/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0469 - root_mean_squared_error: 0.2154 - val_loss: 0.2484 - val_root_mean_squared_error: 0.4984
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.48821
# Epoch 58/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0505 - root_mean_squared_error: 0.2247 - val_loss: 0.2864 - val_root_mean_squared_error: 0.5352
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.48821
# Epoch 59/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0416 - root_mean_squared_error: 0.2036 - val_loss: 0.2506 - val_root_mean_squared_error: 0.5006
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.48821
# Epoch 60/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0300 - root_mean_squared_error: 0.1723 - val_loss: 0.2447 - val_root_mean_squared_error: 0.4947
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.48821
# Epoch 61/70
# 6/6 [==============================] - 4s 837ms/step - loss: 0.0354 - root_mean_squared_error: 0.1872 - val_loss: 0.2412 - val_root_mean_squared_error: 0.4911
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.48821
# Epoch 62/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0265 - root_mean_squared_error: 0.1627 - val_loss: 0.2627 - val_root_mean_squared_error: 0.5126
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.48821
# Epoch 63/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0377 - root_mean_squared_error: 0.1939 - val_loss: 0.2547 - val_root_mean_squared_error: 0.5047
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.48821
# Epoch 64/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0302 - root_mean_squared_error: 0.1734 - val_loss: 0.2511 - val_root_mean_squared_error: 0.5011
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.48821
# Epoch 65/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.0311 - root_mean_squared_error: 0.1758 - val_loss: 0.2539 - val_root_mean_squared_error: 0.5039
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.48821
# Epoch 66/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0317 - root_mean_squared_error: 0.1781 - val_loss: 0.2513 - val_root_mean_squared_error: 0.5013
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.48821
# Epoch 67/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0224 - root_mean_squared_error: 0.1495 - val_loss: 0.2638 - val_root_mean_squared_error: 0.5137
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.48821
# Epoch 68/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0267 - root_mean_squared_error: 0.1632 - val_loss: 0.2593 - val_root_mean_squared_error: 0.5093
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.48821
# Epoch 69/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0157 - root_mean_squared_error: 0.1249 - val_loss: 0.2533 - val_root_mean_squared_error: 0.5033
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.48821
# Epoch 70/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0267 - root_mean_squared_error: 0.1631 - val_loss: 0.2594 - val_root_mean_squared_error: 0.5093
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.48821
# predicting
# 0.48820702419090106
# ************** iteration 2 **************
# tokenization
# Backend Cleared
# Epoch 1/70
# 6/6 [==============================] - 3s 567ms/step - loss: 0.1419 - root_mean_squared_error: 0.3767 - val_loss: 0.0411 - val_root_mean_squared_error: 0.2027
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.20267, saving model to ./result/roberta_weight_fold_2.h5
# Epoch 2/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0828 - root_mean_squared_error: 0.2878 - val_loss: 0.0446 - val_root_mean_squared_error: 0.2113
#
# Epoch 00002: val_root_mean_squared_error did not improve from 0.20267
# Epoch 3/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.0817 - root_mean_squared_error: 0.2859 - val_loss: 0.0381 - val_root_mean_squared_error: 0.1953
#
# Epoch 00003: val_root_mean_squared_error improved from 0.20267 to 0.19528, saving model to ./result/roberta_weight_fold_2.h5
# Epoch 4/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.1129 - root_mean_squared_error: 0.3360 - val_loss: 0.0591 - val_root_mean_squared_error: 0.2430
#
# Epoch 00004: val_root_mean_squared_error did not improve from 0.19528
# Epoch 5/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.1101 - root_mean_squared_error: 0.3318 - val_loss: 0.0806 - val_root_mean_squared_error: 0.2839
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.19528
# Epoch 6/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.1418 - root_mean_squared_error: 0.3765 - val_loss: 0.0796 - val_root_mean_squared_error: 0.2822
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.19528
# Epoch 7/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.1252 - root_mean_squared_error: 0.3538 - val_loss: 0.1421 - val_root_mean_squared_error: 0.3769
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.19528
# Epoch 8/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.1665 - root_mean_squared_error: 0.4080 - val_loss: 0.0765 - val_root_mean_squared_error: 0.2765
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.19528
# Epoch 9/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.1259 - root_mean_squared_error: 0.3549 - val_loss: 0.0613 - val_root_mean_squared_error: 0.2476
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.19528
# Epoch 10/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.1057 - root_mean_squared_error: 0.3251 - val_loss: 0.0702 - val_root_mean_squared_error: 0.2649
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.19528
# Epoch 11/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0906 - root_mean_squared_error: 0.3009 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2335
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.19528
# Epoch 12/70
# 6/6 [==============================] - 4s 822ms/step - loss: 0.1132 - root_mean_squared_error: 0.3364 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2355
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.19528
# Epoch 13/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0752 - root_mean_squared_error: 0.2742 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2184
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.19528
# Epoch 14/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.1147 - root_mean_squared_error: 0.3387 - val_loss: 0.0914 - val_root_mean_squared_error: 0.3024
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.19528
# Epoch 15/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0943 - root_mean_squared_error: 0.3071 - val_loss: 0.0514 - val_root_mean_squared_error: 0.2268
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.19528
# Epoch 16/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0789 - root_mean_squared_error: 0.2809 - val_loss: 0.0529 - val_root_mean_squared_error: 0.2301
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.19528
# Epoch 17/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0719 - root_mean_squared_error: 0.2682 - val_loss: 0.0661 - val_root_mean_squared_error: 0.2572
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.19528
# Epoch 18/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0724 - root_mean_squared_error: 0.2691 - val_loss: 0.0744 - val_root_mean_squared_error: 0.2728
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.19528
# Epoch 19/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0692 - root_mean_squared_error: 0.2631 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2356
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.19528
# Epoch 20/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0708 - root_mean_squared_error: 0.2660 - val_loss: 0.0652 - val_root_mean_squared_error: 0.2553
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.19528
# Epoch 21/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.1001 - root_mean_squared_error: 0.3165 - val_loss: 0.0863 - val_root_mean_squared_error: 0.2937
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.19528
# Epoch 22/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0768 - root_mean_squared_error: 0.2772 - val_loss: 0.0723 - val_root_mean_squared_error: 0.2689
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.19528
# Epoch 23/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0677 - root_mean_squared_error: 0.2601 - val_loss: 0.0776 - val_root_mean_squared_error: 0.2786
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.19528
# Epoch 24/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0513 - root_mean_squared_error: 0.2266 - val_loss: 0.0603 - val_root_mean_squared_error: 0.2455
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.19528
# Epoch 25/70
# 6/6 [==============================] - 3s 542ms/step - loss: 0.0565 - root_mean_squared_error: 0.2377 - val_loss: 0.0541 - val_root_mean_squared_error: 0.2325
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.19528
# Epoch 26/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0500 - root_mean_squared_error: 0.2235 - val_loss: 0.1109 - val_root_mean_squared_error: 0.3329
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.19528
# Epoch 27/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0671 - root_mean_squared_error: 0.2591 - val_loss: 0.0676 - val_root_mean_squared_error: 0.2600
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.19528
# Epoch 28/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0635 - root_mean_squared_error: 0.2520 - val_loss: 0.0506 - val_root_mean_squared_error: 0.2249
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.19528
# Epoch 29/70
# 6/6 [==============================] - 3s 545ms/step - loss: 0.0504 - root_mean_squared_error: 0.2245 - val_loss: 0.0511 - val_root_mean_squared_error: 0.2260
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.19528
# Epoch 30/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0338 - root_mean_squared_error: 0.1838 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2474
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.19528
# Epoch 31/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0543 - root_mean_squared_error: 0.2330 - val_loss: 0.0566 - val_root_mean_squared_error: 0.2379
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.19528
# Epoch 32/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107 - val_loss: 0.0512 - val_root_mean_squared_error: 0.2263
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.19528
# Epoch 33/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0368 - root_mean_squared_error: 0.1919 - val_loss: 0.0602 - val_root_mean_squared_error: 0.2454
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.19528
# Epoch 34/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0418 - root_mean_squared_error: 0.2044 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2576
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.19528
# Epoch 35/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0296 - root_mean_squared_error: 0.1719 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2317
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.19528
# Epoch 36/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0335 - root_mean_squared_error: 0.1831 - val_loss: 0.0694 - val_root_mean_squared_error: 0.2635
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.19528
# Epoch 37/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0295 - root_mean_squared_error: 0.1717 - val_loss: 0.0621 - val_root_mean_squared_error: 0.2492
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.19528
# Epoch 38/70
# 6/6 [==============================] - 3s 561ms/step - loss: 0.0261 - root_mean_squared_error: 0.1617 - val_loss: 0.0558 - val_root_mean_squared_error: 0.2363
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.19528
# Epoch 39/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0226 - root_mean_squared_error: 0.1505 - val_loss: 0.0517 - val_root_mean_squared_error: 0.2275
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.19528
# Epoch 40/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0256 - root_mean_squared_error: 0.1599 - val_loss: 0.0545 - val_root_mean_squared_error: 0.2334
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.19528
# Epoch 41/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0276 - root_mean_squared_error: 0.1662 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2540
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.19528
# Epoch 42/70
# 6/6 [==============================] - 4s 839ms/step - loss: 0.0224 - root_mean_squared_error: 0.1497 - val_loss: 0.0482 - val_root_mean_squared_error: 0.2196
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.19528
# Epoch 43/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0303 - root_mean_squared_error: 0.1742 - val_loss: 0.0522 - val_root_mean_squared_error: 0.2285
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.19528
# Epoch 44/70
# 6/6 [==============================] - 3s 563ms/step - loss: 0.0198 - root_mean_squared_error: 0.1406 - val_loss: 0.0622 - val_root_mean_squared_error: 0.2495
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.19528
# Epoch 45/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0159 - root_mean_squared_error: 0.1262 - val_loss: 0.0550 - val_root_mean_squared_error: 0.2345
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.19528
# Epoch 46/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0234 - root_mean_squared_error: 0.1531 - val_loss: 0.0491 - val_root_mean_squared_error: 0.2215
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.19528
# Epoch 47/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0190 - root_mean_squared_error: 0.1377 - val_loss: 0.0544 - val_root_mean_squared_error: 0.2331
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.19528
# Epoch 48/70
# 6/6 [==============================] - 3s 560ms/step - loss: 0.0211 - root_mean_squared_error: 0.1453 - val_loss: 0.0537 - val_root_mean_squared_error: 0.2318
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.19528
# Epoch 49/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0141 - root_mean_squared_error: 0.1188 - val_loss: 0.0528 - val_root_mean_squared_error: 0.2299
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.19528
# Epoch 50/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0189 - root_mean_squared_error: 0.1374 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2301
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.19528
# Epoch 51/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0211 - root_mean_squared_error: 0.1451 - val_loss: 0.0536 - val_root_mean_squared_error: 0.2315
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.19528
# Epoch 52/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0162 - root_mean_squared_error: 0.1273 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.19528
# Epoch 53/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0167 - root_mean_squared_error: 0.1292 - val_loss: 0.0609 - val_root_mean_squared_error: 0.2468
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.19528
# Epoch 54/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0157 - root_mean_squared_error: 0.1253 - val_loss: 0.0579 - val_root_mean_squared_error: 0.2407
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.19528
# Epoch 55/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0199 - root_mean_squared_error: 0.1412 - val_loss: 0.0507 - val_root_mean_squared_error: 0.2253
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.19528
# Epoch 56/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0157 - root_mean_squared_error: 0.1254 - val_loss: 0.0556 - val_root_mean_squared_error: 0.2358
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.19528
# Epoch 57/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0145 - root_mean_squared_error: 0.1205 - val_loss: 0.0508 - val_root_mean_squared_error: 0.2253
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.19528
# Epoch 58/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0096 - root_mean_squared_error: 0.0979 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.19528
# Epoch 59/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0101 - root_mean_squared_error: 0.1003 - val_loss: 0.0506 - val_root_mean_squared_error: 0.2249
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.19528
# Epoch 60/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0128 - root_mean_squared_error: 0.1133 - val_loss: 0.0510 - val_root_mean_squared_error: 0.2259
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.19528
# Epoch 61/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0127 - root_mean_squared_error: 0.1127 - val_loss: 0.0576 - val_root_mean_squared_error: 0.2400
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.19528
# Epoch 62/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0532 - val_root_mean_squared_error: 0.2307
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.19528
# Epoch 63/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0107 - root_mean_squared_error: 0.1034 - val_loss: 0.0500 - val_root_mean_squared_error: 0.2235
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.19528
# Epoch 64/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0111 - root_mean_squared_error: 0.1054 - val_loss: 0.0525 - val_root_mean_squared_error: 0.2291
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.19528
# Epoch 65/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0127 - root_mean_squared_error: 0.1129 - val_loss: 0.0532 - val_root_mean_squared_error: 0.2307
#
# Epoch 00065: val_root_mean_squared_error did not improve from 0.19528
# Epoch 66/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0113 - root_mean_squared_error: 0.1061 - val_loss: 0.0547 - val_root_mean_squared_error: 0.2340
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.19528
# Epoch 67/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0080 - root_mean_squared_error: 0.0897 - val_loss: 0.0531 - val_root_mean_squared_error: 0.2304
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.19528
# Epoch 68/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0073 - root_mean_squared_error: 0.0854 - val_loss: 0.0529 - val_root_mean_squared_error: 0.2299
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.19528
# Epoch 69/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0076 - root_mean_squared_error: 0.0873 - val_loss: 0.0477 - val_root_mean_squared_error: 0.2184
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.19528
# Epoch 70/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0098 - root_mean_squared_error: 0.0992 - val_loss: 0.0470 - val_root_mean_squared_error: 0.2167
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.19528
# predicting
# 0.1952786682126204
# ************** iteration 3 **************
# tokenization
# Backend Cleared
# Epoch 1/70
# 6/6 [==============================] - 3s 560ms/step - loss: 0.0975 - root_mean_squared_error: 0.3123 - val_loss: 0.0721 - val_root_mean_squared_error: 0.2685
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 0.26853, saving model to ./result/roberta_weight_fold_3.h5
# Epoch 2/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0964 - root_mean_squared_error: 0.3104 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2401
#
# Epoch 00002: val_root_mean_squared_error improved from 0.26853 to 0.24010, saving model to ./result/roberta_weight_fold_3.h5
# Epoch 3/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.1288 - root_mean_squared_error: 0.3589 - val_loss: 0.0864 - val_root_mean_squared_error: 0.2939
#
# Epoch 00003: val_root_mean_squared_error did not improve from 0.24010
# Epoch 4/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.1008 - root_mean_squared_error: 0.3175 - val_loss: 0.0524 - val_root_mean_squared_error: 0.2289
#
# Epoch 00004: val_root_mean_squared_error improved from 0.24010 to 0.22894, saving model to ./result/roberta_weight_fold_3.h5
# Epoch 5/70
# 6/6 [==============================] - 3s 563ms/step - loss: 0.1355 - root_mean_squared_error: 0.3681 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2373
#
# Epoch 00005: val_root_mean_squared_error did not improve from 0.22894
# Epoch 6/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0944 - root_mean_squared_error: 0.3072 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2524
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.22894
# Epoch 7/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0977 - root_mean_squared_error: 0.3126 - val_loss: 0.0705 - val_root_mean_squared_error: 0.2655
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.22894
# Epoch 8/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0831 - root_mean_squared_error: 0.2883 - val_loss: 0.0526 - val_root_mean_squared_error: 0.2293
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.22894
# Epoch 9/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0989 - root_mean_squared_error: 0.3144 - val_loss: 0.0677 - val_root_mean_squared_error: 0.2602
#
# Epoch 00009: val_root_mean_squared_error did not improve from 0.22894
# Epoch 10/70
# 6/6 [==============================] - 3s 545ms/step - loss: 0.0858 - root_mean_squared_error: 0.2929 - val_loss: 0.0627 - val_root_mean_squared_error: 0.2505
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.22894
# Epoch 11/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0654 - root_mean_squared_error: 0.2557 - val_loss: 0.0669 - val_root_mean_squared_error: 0.2587
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.22894
# Epoch 12/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.1267 - root_mean_squared_error: 0.3560 - val_loss: 0.0605 - val_root_mean_squared_error: 0.2460
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.22894
# Epoch 13/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0907 - root_mean_squared_error: 0.3012 - val_loss: 0.0693 - val_root_mean_squared_error: 0.2633
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.22894
# Epoch 14/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0665 - root_mean_squared_error: 0.2578 - val_loss: 0.1531 - val_root_mean_squared_error: 0.3913
#
# Epoch 00014: val_root_mean_squared_error did not improve from 0.22894
# Epoch 15/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.1015 - root_mean_squared_error: 0.3185 - val_loss: 0.1056 - val_root_mean_squared_error: 0.3249
#
# Epoch 00015: val_root_mean_squared_error did not improve from 0.22894
# Epoch 16/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0748 - root_mean_squared_error: 0.2735 - val_loss: 0.0612 - val_root_mean_squared_error: 0.2473
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.22894
# Epoch 17/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.0599 - root_mean_squared_error: 0.2447 - val_loss: 0.0657 - val_root_mean_squared_error: 0.2562
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.22894
# Epoch 18/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0684 - root_mean_squared_error: 0.2616 - val_loss: 0.0718 - val_root_mean_squared_error: 0.2680
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.22894
# Epoch 19/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0777 - root_mean_squared_error: 0.2787 - val_loss: 0.0777 - val_root_mean_squared_error: 0.2787
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.22894
# Epoch 20/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0670 - root_mean_squared_error: 0.2588 - val_loss: 0.0570 - val_root_mean_squared_error: 0.2387
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.22894
# Epoch 21/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0598 - root_mean_squared_error: 0.2446 - val_loss: 0.0563 - val_root_mean_squared_error: 0.2373
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.22894
# Epoch 22/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0562 - root_mean_squared_error: 0.2371 - val_loss: 0.0617 - val_root_mean_squared_error: 0.2485
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.22894
# Epoch 23/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0559 - root_mean_squared_error: 0.2364 - val_loss: 0.0637 - val_root_mean_squared_error: 0.2524
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.22894
# Epoch 24/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0581 - root_mean_squared_error: 0.2410 - val_loss: 0.0620 - val_root_mean_squared_error: 0.2491
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.22894
# Epoch 25/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0721 - root_mean_squared_error: 0.2684 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2540
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.22894
# Epoch 26/70
# 6/6 [==============================] - 3s 567ms/step - loss: 0.0459 - root_mean_squared_error: 0.2143 - val_loss: 0.0664 - val_root_mean_squared_error: 0.2576
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.22894
# Epoch 27/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0636 - root_mean_squared_error: 0.2523 - val_loss: 0.0671 - val_root_mean_squared_error: 0.2589
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.22894
# Epoch 28/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0444 - root_mean_squared_error: 0.2107 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2417
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.22894
# Epoch 29/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0375 - root_mean_squared_error: 0.1936 - val_loss: 0.0584 - val_root_mean_squared_error: 0.2417
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.22894
# Epoch 30/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0328 - root_mean_squared_error: 0.1812 - val_loss: 0.0719 - val_root_mean_squared_error: 0.2682
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.22894
# Epoch 31/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0500 - root_mean_squared_error: 0.2236 - val_loss: 0.0577 - val_root_mean_squared_error: 0.2401
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.22894
# Epoch 32/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0437 - root_mean_squared_error: 0.2091 - val_loss: 0.0641 - val_root_mean_squared_error: 0.2531
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.22894
# Epoch 33/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0441 - root_mean_squared_error: 0.2100 - val_loss: 0.0566 - val_root_mean_squared_error: 0.2378
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.22894
# Epoch 34/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.0303 - root_mean_squared_error: 0.1742 - val_loss: 0.0523 - val_root_mean_squared_error: 0.2288
#
# Epoch 00034: val_root_mean_squared_error improved from 0.22894 to 0.22878, saving model to ./result/roberta_weight_fold_3.h5
# Epoch 35/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0447 - root_mean_squared_error: 0.2113 - val_loss: 0.1017 - val_root_mean_squared_error: 0.3190
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.22878
# Epoch 36/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0543 - root_mean_squared_error: 0.2331 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2355
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.22878
# Epoch 37/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0471 - root_mean_squared_error: 0.2170 - val_loss: 0.0869 - val_root_mean_squared_error: 0.2947
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.22878
# Epoch 38/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0422 - root_mean_squared_error: 0.2054 - val_loss: 0.0614 - val_root_mean_squared_error: 0.2478
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.22878
# Epoch 39/70
# 6/6 [==============================] - 4s 831ms/step - loss: 0.0438 - root_mean_squared_error: 0.2094 - val_loss: 0.0555 - val_root_mean_squared_error: 0.2355
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.22878
# Epoch 40/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0360 - root_mean_squared_error: 0.1896 - val_loss: 0.0551 - val_root_mean_squared_error: 0.2348
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.22878
# Epoch 41/70
# 6/6 [==============================] - 3s 545ms/step - loss: 0.0230 - root_mean_squared_error: 0.1515 - val_loss: 0.0608 - val_root_mean_squared_error: 0.2467
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.22878
# Epoch 42/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0331 - root_mean_squared_error: 0.1820 - val_loss: 0.0549 - val_root_mean_squared_error: 0.2342
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.22878
# Epoch 43/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0328 - root_mean_squared_error: 0.1811 - val_loss: 0.0586 - val_root_mean_squared_error: 0.2420
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.22878
# Epoch 44/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0215 - root_mean_squared_error: 0.1467 - val_loss: 0.0529 - val_root_mean_squared_error: 0.2299
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.22878
# Epoch 45/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0277 - root_mean_squared_error: 0.1666 - val_loss: 0.0569 - val_root_mean_squared_error: 0.2385
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.22878
# Epoch 46/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0180 - root_mean_squared_error: 0.1342 - val_loss: 0.0559 - val_root_mean_squared_error: 0.2364
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.22878
# Epoch 47/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482 - val_loss: 0.0530 - val_root_mean_squared_error: 0.2303
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.22878
# Epoch 48/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0220 - root_mean_squared_error: 0.1482 - val_loss: 0.0567 - val_root_mean_squared_error: 0.2381
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.22878
# Epoch 49/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0241 - root_mean_squared_error: 0.1552 - val_loss: 0.0494 - val_root_mean_squared_error: 0.2224
#
# Epoch 00049: val_root_mean_squared_error improved from 0.22878 to 0.22237, saving model to ./result/roberta_weight_fold_3.h5
# Epoch 50/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0187 - root_mean_squared_error: 0.1366 - val_loss: 0.0757 - val_root_mean_squared_error: 0.2751
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.22237
# Epoch 51/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.0282 - root_mean_squared_error: 0.1680 - val_loss: 0.0645 - val_root_mean_squared_error: 0.2540
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.22237
# Epoch 52/70
# ...
#
# Epoch 00006: val_root_mean_squared_error did not improve from 0.09770
# Epoch 7/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.0135 - root_mean_squared_error: 0.1162 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0999
#
# Epoch 00007: val_root_mean_squared_error did not improve from 0.09770
# Epoch 8/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0170 - root_mean_squared_error: 0.1304 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
#
# Epoch 00008: val_root_mean_squared_error did not improve from 0.09770
# Epoch 9/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0148 - root_mean_squared_error: 0.1216 - val_loss: 0.0091 - val_root_mean_squared_error: 0.0955
#
# Epoch 00009: val_root_mean_squared_error improved from 0.09770 to 0.09545, saving model to ./result/roberta_weight_fold_5.h5
# Epoch 10/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0116 - val_root_mean_squared_error: 0.1078
#
# Epoch 00010: val_root_mean_squared_error did not improve from 0.09545
# Epoch 11/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.0097 - root_mean_squared_error: 0.0984 - val_loss: 0.0213 - val_root_mean_squared_error: 0.1459
#
# Epoch 00011: val_root_mean_squared_error did not improve from 0.09545
# Epoch 12/70
# 6/6 [==============================] - 3s 558ms/step - loss: 0.0136 - root_mean_squared_error: 0.1167 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
#
# Epoch 00012: val_root_mean_squared_error did not improve from 0.09545
# Epoch 13/70
# 6/6 [==============================] - 3s 560ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0101 - val_root_mean_squared_error: 0.1003
#
# Epoch 00013: val_root_mean_squared_error did not improve from 0.09545
# Epoch 14/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0144 - root_mean_squared_error: 0.1199 - val_loss: 0.0081 - val_root_mean_squared_error: 0.0902
#
# Epoch 00014: val_root_mean_squared_error improved from 0.09545 to 0.09023, saving model to ./result/roberta_weight_fold_5.h5
# Epoch 15/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0097 - root_mean_squared_error: 0.0986 - val_loss: 0.0075 - val_root_mean_squared_error: 0.0864
#
# Epoch 00015: val_root_mean_squared_error improved from 0.09023 to 0.08643, saving model to ./result/roberta_weight_fold_5.h5
# Epoch 16/70
# 6/6 [==============================] - 3s 550ms/step - loss: 0.0119 - root_mean_squared_error: 0.1092 - val_loss: 0.0090 - val_root_mean_squared_error: 0.0950
#
# Epoch 00016: val_root_mean_squared_error did not improve from 0.08643
# Epoch 17/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.0132 - root_mean_squared_error: 0.1149 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1038
#
# Epoch 00017: val_root_mean_squared_error did not improve from 0.08643
# Epoch 18/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0103 - root_mean_squared_error: 0.1016 - val_loss: 0.0185 - val_root_mean_squared_error: 0.1360
#
# Epoch 00018: val_root_mean_squared_error did not improve from 0.08643
# Epoch 19/70
# 6/6 [==============================] - 3s 564ms/step - loss: 0.0105 - root_mean_squared_error: 0.1026 - val_loss: 0.0077 - val_root_mean_squared_error: 0.0877
#
# Epoch 00019: val_root_mean_squared_error did not improve from 0.08643
# Epoch 20/70
# 6/6 [==============================] - 3s 542ms/step - loss: 0.0151 - root_mean_squared_error: 0.1228 - val_loss: 0.0145 - val_root_mean_squared_error: 0.1204
#
# Epoch 00020: val_root_mean_squared_error did not improve from 0.08643
# Epoch 21/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0156 - root_mean_squared_error: 0.1250 - val_loss: 0.0095 - val_root_mean_squared_error: 0.0975
#
# Epoch 00021: val_root_mean_squared_error did not improve from 0.08643
# Epoch 22/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0104 - root_mean_squared_error: 0.1019 - val_loss: 0.0110 - val_root_mean_squared_error: 0.1048
#
# Epoch 00022: val_root_mean_squared_error did not improve from 0.08643
# Epoch 23/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0119 - root_mean_squared_error: 0.1089 - val_loss: 0.0376 - val_root_mean_squared_error: 0.1940
#
# Epoch 00023: val_root_mean_squared_error did not improve from 0.08643
# Epoch 24/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0164 - root_mean_squared_error: 0.1280 - val_loss: 0.0279 - val_root_mean_squared_error: 0.1669
#
# Epoch 00024: val_root_mean_squared_error did not improve from 0.08643
# Epoch 25/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0182 - root_mean_squared_error: 0.1351 - val_loss: 0.0123 - val_root_mean_squared_error: 0.1109
#
# Epoch 00025: val_root_mean_squared_error did not improve from 0.08643
# Epoch 26/70
# 6/6 [==============================] - 3s 562ms/step - loss: 0.0165 - root_mean_squared_error: 0.1283 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1138
#
# Epoch 00026: val_root_mean_squared_error did not improve from 0.08643
# Epoch 27/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0108 - root_mean_squared_error: 0.1038 - val_loss: 0.0160 - val_root_mean_squared_error: 0.1263
#
# Epoch 00027: val_root_mean_squared_error did not improve from 0.08643
# Epoch 28/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0120 - root_mean_squared_error: 0.1098 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
#
# Epoch 00028: val_root_mean_squared_error did not improve from 0.08643
# Epoch 29/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0113 - root_mean_squared_error: 0.1064 - val_loss: 0.0118 - val_root_mean_squared_error: 0.1084
#
# Epoch 00029: val_root_mean_squared_error did not improve from 0.08643
# Epoch 30/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1034
#
# Epoch 00030: val_root_mean_squared_error did not improve from 0.08643
# Epoch 31/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0108 - root_mean_squared_error: 0.1040 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
#
# Epoch 00031: val_root_mean_squared_error did not improve from 0.08643
# Epoch 32/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0092 - root_mean_squared_error: 0.0958 - val_loss: 0.0196 - val_root_mean_squared_error: 0.1400
#
# Epoch 00032: val_root_mean_squared_error did not improve from 0.08643
# Epoch 33/70
# 6/6 [==============================] - 3s 546ms/step - loss: 0.0125 - root_mean_squared_error: 0.1120 - val_loss: 0.0238 - val_root_mean_squared_error: 0.1543
#
# Epoch 00033: val_root_mean_squared_error did not improve from 0.08643
# Epoch 34/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0168 - root_mean_squared_error: 0.1296 - val_loss: 0.0164 - val_root_mean_squared_error: 0.1280
#
# Epoch 00034: val_root_mean_squared_error did not improve from 0.08643
# Epoch 35/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0117 - root_mean_squared_error: 0.1082 - val_loss: 0.0124 - val_root_mean_squared_error: 0.1112
#
# Epoch 00035: val_root_mean_squared_error did not improve from 0.08643
# Epoch 36/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0118 - root_mean_squared_error: 0.1085 - val_loss: 0.0107 - val_root_mean_squared_error: 0.1037
#
# Epoch 00036: val_root_mean_squared_error did not improve from 0.08643
# Epoch 37/70
# 6/6 [==============================] - 3s 554ms/step - loss: 0.0115 - root_mean_squared_error: 0.1070 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0905
#
# Epoch 00037: val_root_mean_squared_error did not improve from 0.08643
# Epoch 38/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0102 - root_mean_squared_error: 0.1009 - val_loss: 0.0094 - val_root_mean_squared_error: 0.0968
#
# Epoch 00038: val_root_mean_squared_error did not improve from 0.08643
# Epoch 39/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0110 - root_mean_squared_error: 0.1050 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
#
# Epoch 00039: val_root_mean_squared_error did not improve from 0.08643
# Epoch 40/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0105 - root_mean_squared_error: 0.1024 - val_loss: 0.0096 - val_root_mean_squared_error: 0.0981
#
# Epoch 00040: val_root_mean_squared_error did not improve from 0.08643
# Epoch 41/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0084 - root_mean_squared_error: 0.0918 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1028
#
# Epoch 00041: val_root_mean_squared_error did not improve from 0.08643
# Epoch 42/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0077 - root_mean_squared_error: 0.0880 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
#
# Epoch 00042: val_root_mean_squared_error did not improve from 0.08643
# Epoch 43/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0083 - root_mean_squared_error: 0.0908 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1089
#
# Epoch 00043: val_root_mean_squared_error did not improve from 0.08643
# Epoch 44/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0098 - root_mean_squared_error: 0.0991 - val_loss: 0.0122 - val_root_mean_squared_error: 0.1104
#
# Epoch 00044: val_root_mean_squared_error did not improve from 0.08643
# Epoch 45/70
# 6/6 [==============================] - 3s 543ms/step - loss: 0.0118 - root_mean_squared_error: 0.1086 - val_loss: 0.0100 - val_root_mean_squared_error: 0.0998
#
# Epoch 00045: val_root_mean_squared_error did not improve from 0.08643
# Epoch 46/70
# 6/6 [==============================] - 4s 851ms/step - loss: 0.0113 - root_mean_squared_error: 0.1063 - val_loss: 0.0097 - val_root_mean_squared_error: 0.0984
#
# Epoch 00046: val_root_mean_squared_error did not improve from 0.08643
# Epoch 47/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0129 - root_mean_squared_error: 0.1138 - val_loss: 0.0083 - val_root_mean_squared_error: 0.0911
#
# Epoch 00047: val_root_mean_squared_error did not improve from 0.08643
# Epoch 48/70
# 6/6 [==============================] - 3s 559ms/step - loss: 0.0095 - root_mean_squared_error: 0.0972 - val_loss: 0.0183 - val_root_mean_squared_error: 0.1351
#
# Epoch 00048: val_root_mean_squared_error did not improve from 0.08643
# Epoch 49/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0106 - root_mean_squared_error: 0.1027 - val_loss: 0.0172 - val_root_mean_squared_error: 0.1310
#
# Epoch 00049: val_root_mean_squared_error did not improve from 0.08643
# Epoch 50/70
# 6/6 [==============================] - 3s 557ms/step - loss: 0.0089 - root_mean_squared_error: 0.0945 - val_loss: 0.0206 - val_root_mean_squared_error: 0.1435
#
# Epoch 00050: val_root_mean_squared_error did not improve from 0.08643
# Epoch 51/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0098 - root_mean_squared_error: 0.0990 - val_loss: 0.0133 - val_root_mean_squared_error: 0.1154
#
# Epoch 00051: val_root_mean_squared_error did not improve from 0.08643
# Epoch 52/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0138 - root_mean_squared_error: 0.1176 - val_loss: 0.0115 - val_root_mean_squared_error: 0.1074
#
# Epoch 00052: val_root_mean_squared_error did not improve from 0.08643
# Epoch 53/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0120 - root_mean_squared_error: 0.1094 - val_loss: 0.0103 - val_root_mean_squared_error: 0.1013
#
# Epoch 00053: val_root_mean_squared_error did not improve from 0.08643
# Epoch 54/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0128 - root_mean_squared_error: 0.1132 - val_loss: 0.0106 - val_root_mean_squared_error: 0.1029
#
# Epoch 00054: val_root_mean_squared_error did not improve from 0.08643
# Epoch 55/70
# 6/6 [==============================] - 3s 545ms/step - loss: 0.0087 - root_mean_squared_error: 0.0933 - val_loss: 0.0098 - val_root_mean_squared_error: 0.0992
#
# Epoch 00055: val_root_mean_squared_error did not improve from 0.08643
# Epoch 56/70
# 6/6 [==============================] - 3s 553ms/step - loss: 0.0120 - root_mean_squared_error: 0.1098 - val_loss: 0.0119 - val_root_mean_squared_error: 0.1091
#
# Epoch 00056: val_root_mean_squared_error did not improve from 0.08643
# Epoch 57/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0142 - root_mean_squared_error: 0.1191 - val_loss: 0.0135 - val_root_mean_squared_error: 0.1160
#
# Epoch 00057: val_root_mean_squared_error did not improve from 0.08643
# Epoch 58/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0121 - root_mean_squared_error: 0.1102 - val_loss: 0.0157 - val_root_mean_squared_error: 0.1251
#
# Epoch 00058: val_root_mean_squared_error did not improve from 0.08643
# Epoch 59/70
# 6/6 [==============================] - 3s 551ms/step - loss: 0.0070 - root_mean_squared_error: 0.0834 - val_loss: 0.0082 - val_root_mean_squared_error: 0.0903
#
# Epoch 00059: val_root_mean_squared_error did not improve from 0.08643
# Epoch 60/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0094 - root_mean_squared_error: 0.0967 - val_loss: 0.0088 - val_root_mean_squared_error: 0.0939
#
# Epoch 00060: val_root_mean_squared_error did not improve from 0.08643
# Epoch 61/70
# 6/6 [==============================] - 3s 544ms/step - loss: 0.0103 - root_mean_squared_error: 0.1013 - val_loss: 0.0130 - val_root_mean_squared_error: 0.1140
#
# Epoch 00061: val_root_mean_squared_error did not improve from 0.08643
# Epoch 62/70
# 6/6 [==============================] - 3s 547ms/step - loss: 0.0126 - root_mean_squared_error: 0.1124 - val_loss: 0.0162 - val_root_mean_squared_error: 0.1274
#
# Epoch 00062: val_root_mean_squared_error did not improve from 0.08643
# Epoch 63/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0091 - root_mean_squared_error: 0.0953 - val_loss: 0.0200 - val_root_mean_squared_error: 0.1414
#
# Epoch 00063: val_root_mean_squared_error did not improve from 0.08643
# Epoch 64/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0112 - root_mean_squared_error: 0.1058 - val_loss: 0.0080 - val_root_mean_squared_error: 0.0892
#
# Epoch 00064: val_root_mean_squared_error did not improve from 0.08643
# Epoch 65/70
# 6/6 [==============================] - 3s 552ms/step - loss: 0.0079 - root_mean_squared_error: 0.0890 - val_loss: 0.0072 - val_root_mean_squared_error: 0.0851
#
# Epoch 00065: val_root_mean_squared_error improved from 0.08643 to 0.08512, saving model to ./result/roberta_weight_fold_5.h5
# Epoch 66/70
# 6/6 [==============================] - 3s 545ms/step - loss: 0.0081 - root_mean_squared_error: 0.0901 - val_loss: 0.0092 - val_root_mean_squared_error: 0.0959
#
# Epoch 00066: val_root_mean_squared_error did not improve from 0.08512
# Epoch 67/70
# 6/6 [==============================] - 3s 556ms/step - loss: 0.0071 - root_mean_squared_error: 0.0842 - val_loss: 0.0089 - val_root_mean_squared_error: 0.0943
#
# Epoch 00067: val_root_mean_squared_error did not improve from 0.08512
# Epoch 68/70
# 6/6 [==============================] - 3s 555ms/step - loss: 0.0059 - root_mean_squared_error: 0.0769 - val_loss: 0.0084 - val_root_mean_squared_error: 0.0918
#
# Epoch 00068: val_root_mean_squared_error did not improve from 0.08512
# Epoch 69/70
# 6/6 [==============================] - 3s 549ms/step - loss: 0.0077 - root_mean_squared_error: 0.0878 - val_loss: 0.0108 - val_root_mean_squared_error: 0.1041
#
# Epoch 00069: val_root_mean_squared_error did not improve from 0.08512
# Epoch 70/70
# 6/6 [==============================] - 3s 548ms/step - loss: 0.0075 - root_mean_squared_error: 0.0868 - val_loss: 0.0132 - val_root_mean_squared_error: 0.1148
#
# Epoch 00070: val_root_mean_squared_error did not improve from 0.08512
# predicting
# 0.08511741759628409
# the final average rmse is  0.22171091823095618
